# %%
#to enable visualizations 
# %matplotlib inline

# First, import pandas, a useful data analysis tool especially when working with labeled data
import pandas as pd

# import seaborn, visualization library in python 
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)

# Next, we'll load the cereal dataset, which is in the specified directory below
cereal = pd.read_csv("C:\\Users\\oddin\\Desktop\\GITHUBPROJECTS\\DV-project2\\cereal.csv")

# Next, display the first 15 rows and all columns of the iris dataframe, good way to see the colum headings for the dataset
cereal.head(15)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 7                     Basic 4   G    C       130        3    2     210    2.0
# 8                   Bran Chex   R    C        90        2    1     200    4.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# ...

# %%
#To visulize the data by creating a barplot
fig,ax = plt.subplots(figsize=(10,10))
cereal['mfr'].value_counts(sort=False).plot(kind='bar',color = 'blue')
plt.title('Cereal Brands and Nutritional Information',fontsize=20)
plt.xlabel('name',fontsize=20)
plt.ylabel('calories',fontsize=20)# Use the .plot extension from Pandas dataframes to plot things

# %%
# Use the .plot extension from Pandas dataframes to plot things
# Use this to make a scatterplot of the Iris features-sepallengthcm on the x-axis and sepalwidthcm on the y-axis.
#df.plot(kind='pie',x=df['name'],y=df['calories'])
df1.plot(kind='line')

# %%
df1 = pd.read_csv("C:\\Users\\oddin\\Desktop\\GITHUBPROJECTS\\DV-project2\\cereal.csv",index_col='name')
df1
# Out:
#                                        mfr type  calories  protein  fat  \
# name
# 100% Bran                                N    C        70        4    1
# 100% Natural Bran                        Q    C       120        3    5
# All-Bran                                 K    C        70        4    1
# All-Bran with Extra Fiber                K    C        50        4    0
# Almond Delight                           R    C       110        2    2
# Apple Cinnamon Cheerios                  G    C       110        2    2
# Apple Jacks                              K    C       110        2    0
# Basic 4                                  G    C       130        3    2
# Bran Chex                                R    C        90        2    1
# Bran Flakes                              P    C        90        3    0
# Cap'n'Crunch                             Q    C       120        1    2
# Cheerios                                 G    C       110        6    2
# ...

# %%
df2=df1[['calories']]
df2
# Out:
#                                         calories
# name
# 100% Bran                                     70
# 100% Natural Bran                            120
# All-Bran                                      70
# All-Bran with Extra Fiber                     50
# Almond Delight                               110
# Apple Cinnamon Cheerios                      110
# Apple Jacks                                  110
# Basic 4                                      130
# Bran Chex                                     90
# Bran Flakes                                   90
# Cap'n'Crunch                                 120
# Cheerios                                     110
# Cinnamon Toast Crunch                        120
# Clusters                                     110
# Cocoa Puffs                                  110
# Corn Chex                                    110
# Corn Flakes                                  100
# Corn Pops                                    110
# ...

# %%
df2.plot(kind='bar',rot=90)

# %%
df3=df1[['rating','calories']]

# %%
df3.plot.pie(y='calories',)

# %%
df3.plot.scatter(x='calories',y='rating')

# %%
df3.plot.box()
